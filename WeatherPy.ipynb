# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
requests.__version__
import time
from datetime import datetime


from config import *

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 636

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

#url ="api.openweathermap.org/data/2.5/weather?q=" + weather_api_key               &APPID

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=825b4f9d7db94dffe76afa90bcc7ef84

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)   

#this will generate a link that will proivide the same output as the line of code below
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=825b4f9d7db94dffe76afa90bcc7ef84&q=Boston

# %%
city_url_Boston= requests.get(city_url).json()
print(city_url_Boston)
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.03, 'feels_like': 73.53, 'temp_min': 70.95, 'temp_max': 76.28, 'pressure': 1015, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 190}, 'clouds': {'all': 100}, 'dt': 1654641438, 'sys': {'type': 2, 'id': 2013408, 'country': 'US', 'sunrise': 1654592877, 'sunset': 1654647513}, 'timezone': -14400, 'id': 4930956, 'name': 'Boston', 'cod': 200}

# %%
# To get a list of Keys from our search would be:
city_Boston_Keys = city_url_Boston.keys()
city_Boston_Keys
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
# To determine the value at eacch Key such as main:

city_url_Boston.get('weather')
# Out:
# [{'id': 804,
#   'main': 'Clouds',
#   'description': 'overcast clouds',
#   'icon': '04d'}]

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 74.05,
#   'feels_like': 73.54,
#   'temp_min': 70.95,
#   'temp_max': 76.28,
#   'pressure': 1015,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 190},
#  'clouds': {'all': 100},
#  'dt': 1654641369,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1654592877,
#   'sunset': 1654647513},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 74.03,
#   'feels_like': 73.53,
#   'temp_min': 70.95,
#   'temp_max': 76.28,
#   'pressure': 1015,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 190},
#  'clouds': {'all': 100},
#  'dt': 1654641438,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1654592877,
#   'sunset': 1654647513},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# WE're now delving into the dictionary of data in correspondance to 'sys' and cannot access other keys
    # This is different from the dictionary list we found from Boston or city_weather.json() 
    # since its embedded inside the Boston list
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1654592877,
#  'sunset': 1654647513}

# %%
# We'll now dive into the 'sys' dictionary and access its Keys
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data['weather'][0]['description']
# Out:
# 'overcast clouds'

# %%
boston_data['dt']
# Out:
# 1654641438

# %%
# Using similar syntax to get the:
    # time of day, we can get the latitude, longitude, maximum temperature, humidity, percent cloudiness, and wind speed
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 76.28 51 100 16.11

# %%
#### Datetime Conversion
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
# .utcfromtimestamp(date) this chain lets us convert the unicode of date generated from boston_data['dt']
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %I:%M:%S:%p')

# the .strftime('%Y-%m-%d %H:%M:%S') formats the datetime conversion into something more readable
# https://docs.python.org/3.7/library/datetime.html#strftime-and-strptime-behavior
# Out:
# '2022-06-07 10:37:18:PM'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(15)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | ishurdi
# Processing Record 3 of Set 1 | olafsvik
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | chino valley
# Processing Record 6 of Set 1 | nikel
# Processing Record 7 of Set 1 | salalah
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | okakarara
# Processing Record 10 of Set 1 | jitra
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | port-gentil
# Processing Record 15 of Set 1 | kolochava
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | nzerekore
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | vardo
# Processing Record 22 of Set 1 | lewisville
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | kaeo
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | terracina
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | hammerfest
# Processing Record 34 of Set 1 | vestmannaeyjar
# Processing Record 35 of Set 1 | paamiut
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | kulhudhuffushi
# Processing Record 38 of Set 1 | kudahuvadhoo
# Processing Record 39 of Set 1 | miyazu
# Processing Record 40 of Set 1 | xinzhi
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | bathsheba
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | albion
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | dali
# Processing Record 2 of Set 2 | nemuro
# Processing Record 3 of Set 2 | amozoc
# City not found. Skipping...
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | grindavik
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | strezhevoy
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | progreso
# Processing Record 17 of Set 2 | tupik
# Processing Record 18 of Set 2 | naze
# Processing Record 19 of Set 2 | wawa
# Processing Record 20 of Set 2 | miramar
# Processing Record 21 of Set 2 | easton
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | skjervoy
# Processing Record 26 of Set 2 | caravelas
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | shache
# Processing Record 29 of Set 2 | beloha
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | tigil
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | mayo
# Processing Record 39 of Set 2 | pontian kecil
# Processing Record 40 of Set 2 | bohl-iggelheim
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | mersing
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | boysun
# Processing Record 3 of Set 3 | amuntai
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | severnyy
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | kapoeta
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | sangar
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | skibbereen
# Processing Record 15 of Set 3 | ostrovnoy
# Processing Record 16 of Set 3 | omboue
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | manthani
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | zumpahuacan
# Processing Record 21 of Set 3 | sisimiut
# Processing Record 22 of Set 3 | half moon bay
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | santa isabel do rio negro
# Processing Record 25 of Set 3 | port hedland
# Processing Record 26 of Set 3 | olds
# Processing Record 27 of Set 3 | angoche
# Processing Record 28 of Set 3 | muli
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | turukhansk
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | oranjemund
# Processing Record 35 of Set 3 | gambela
# Processing Record 36 of Set 3 | ancud
# Processing Record 37 of Set 3 | bar harbor
# Processing Record 38 of Set 3 | sharjah
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | yining
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | ahuimanu
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | akureyri
# Processing Record 47 of Set 3 | saint anthony
# Processing Record 48 of Set 3 | kampot
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | moose factory
# Processing Record 1 of Set 4 | gat
# Processing Record 2 of Set 4 | san quintin
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | samtredia
# Processing Record 5 of Set 4 | mitu
# Processing Record 6 of Set 4 | tianpeng
# Processing Record 7 of Set 4 | stokmarknes
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | kuva
# City not found. Skipping...
# Processing Record 10 of Set 4 | bairiki
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | cairns
# Processing Record 13 of Set 4 | kapaa
# Processing Record 14 of Set 4 | ramhormoz
# Processing Record 15 of Set 4 | berga
# Processing Record 16 of Set 4 | chulumani
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | koutsouras
# Processing Record 19 of Set 4 | tiznit
# Processing Record 20 of Set 4 | pahrump
# Processing Record 21 of Set 4 | luocheng
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | manbij
# Processing Record 24 of Set 4 | azogues
# Processing Record 25 of Set 4 | marinette
# Processing Record 26 of Set 4 | tuatapere
# Processing Record 27 of Set 4 | roald
# Processing Record 28 of Set 4 | port moresby
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | saskylakh
# Processing Record 31 of Set 4 | itoman
# Processing Record 32 of Set 4 | digapahandi
# Processing Record 33 of Set 4 | whyalla
# Processing Record 34 of Set 4 | elizabeth city
# Processing Record 35 of Set 4 | sao gabriel da cachoeira
# Processing Record 36 of Set 4 | nizhnyaya tura
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | key biscayne
# Processing Record 39 of Set 4 | noumea
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | tsuyama
# Processing Record 42 of Set 4 | tual
# Processing Record 43 of Set 4 | roma
# Processing Record 44 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 4 | cabedelo
# Processing Record 46 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 4 | hamina
# Processing Record 48 of Set 4 | rio gallegos
# Processing Record 49 of Set 4 | burns lake
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | ostersund
# Processing Record 2 of Set 5 | charlestown
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | jalingo
# Processing Record 6 of Set 5 | peniche
# Processing Record 7 of Set 5 | ngunguru
# Processing Record 8 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 5 | malacacheta
# Processing Record 10 of Set 5 | fulton
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | meget
# Processing Record 13 of Set 5 | ulundi
# Processing Record 14 of Set 5 | hamilton
# Processing Record 15 of Set 5 | batuan
# Processing Record 16 of Set 5 | trat
# Processing Record 17 of Set 5 | kinsale
# Processing Record 18 of Set 5 | santa maria
# Processing Record 19 of Set 5 | jimo
# Processing Record 20 of Set 5 | upernavik
# Processing Record 21 of Set 5 | kushima
# Processing Record 22 of Set 5 | tabuk
# Processing Record 23 of Set 5 | kidal
# Processing Record 24 of Set 5 | alice springs
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | srednekolymsk
# Processing Record 27 of Set 5 | olavarria
# Processing Record 28 of Set 5 | arzgir
# Processing Record 29 of Set 5 | kavali
# Processing Record 30 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 5 | ugoofaaru
# Processing Record 32 of Set 5 | yulara
# Processing Record 33 of Set 5 | eirunepe
# Processing Record 34 of Set 5 | bac lieu
# Processing Record 35 of Set 5 | north bend
# Processing Record 36 of Set 5 | nabire
# Processing Record 37 of Set 5 | tuktoyaktuk
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 5 | seoul
# Processing Record 41 of Set 5 | evensk
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | sitka
# Processing Record 44 of Set 5 | lompoc
# Processing Record 45 of Set 5 | sarkand
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | havre-saint-pierre
# Processing Record 48 of Set 5 | jining
# Processing Record 49 of Set 5 | holme
# Processing Record 50 of Set 5 | buala
# Processing Record 1 of Set 6 | esmeraldas
# Processing Record 2 of Set 6 | cardinal
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | lebu
# Processing Record 5 of Set 6 | camopi
# Processing Record 6 of Set 6 | mbaiki
# Processing Record 7 of Set 6 | carlsbad
# Processing Record 8 of Set 6 | leh
# Processing Record 9 of Set 6 | necochea
# Processing Record 10 of Set 6 | gorlitz
# Processing Record 11 of Set 6 | iquique
# Processing Record 12 of Set 6 | kurchum
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | vitimskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | puerto lleras
# Processing Record 17 of Set 6 | provideniya
# Processing Record 18 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 19 of Set 6 | ibiracu
# Processing Record 20 of Set 6 | turbat
# Processing Record 21 of Set 6 | pitimbu
# Processing Record 22 of Set 6 | huimanguillo
# Processing Record 23 of Set 6 | tocopilla
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | cayenne
# Processing Record 26 of Set 6 | mar del plata
# Processing Record 27 of Set 6 | sobolevo
# Processing Record 28 of Set 6 | aloleng
# Processing Record 29 of Set 6 | taitung
# Processing Record 30 of Set 6 | stavern
# Processing Record 31 of Set 6 | marietta
# Processing Record 32 of Set 6 | general roca
# Processing Record 33 of Set 6 | ambon
# Processing Record 34 of Set 6 | fos-sur-mer
# Processing Record 35 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 6 | atasu
# Processing Record 37 of Set 6 | trinidad
# Processing Record 38 of Set 6 | birao
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | mwinilunga
# Processing Record 42 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 6 | lewistown
# Processing Record 44 of Set 6 | shakawe
# Processing Record 45 of Set 6 | catamarca
# Processing Record 46 of Set 6 | sarangani
# Processing Record 47 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 48 of Set 6 | denia
# Processing Record 49 of Set 6 | biltine
# Processing Record 50 of Set 6 | am timan
# Processing Record 1 of Set 7 | porto real do colegio
# Processing Record 2 of Set 7 | ponta do sol
# Processing Record 3 of Set 7 | nikki
# Processing Record 4 of Set 7 | kieta
# Processing Record 5 of Set 7 | inhambane
# Processing Record 6 of Set 7 | fairview
# Processing Record 7 of Set 7 | jiayuguan
# Processing Record 8 of Set 7 | balaguer
# Processing Record 9 of Set 7 | zhigansk
# Processing Record 10 of Set 7 | loubomo
# Processing Record 11 of Set 7 | krasnoselkup
# Processing Record 12 of Set 7 | mogadishu
# Processing Record 13 of Set 7 | tallahassee
# Processing Record 14 of Set 7 | poum
# Processing Record 15 of Set 7 | sarishabari
# Processing Record 16 of Set 7 | sao joao da barra
# Processing Record 17 of Set 7 | jieshi
# Processing Record 18 of Set 7 | paciran
# Processing Record 19 of Set 7 | yeppoon
# Processing Record 20 of Set 7 | ayagoz
# Processing Record 21 of Set 7 | vostok
# Processing Record 22 of Set 7 | dondaicha
# Processing Record 23 of Set 7 | arlit
# Processing Record 24 of Set 7 | odoyev
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | onufriyivka
# Processing Record 27 of Set 7 | santa rosa
# Processing Record 28 of Set 7 | gikalo
# City not found. Skipping...
# Processing Record 29 of Set 7 | ipixuna
# Processing Record 30 of Set 7 | sao filipe
# Processing Record 31 of Set 7 | kununurra
# Processing Record 32 of Set 7 | kharp
# Processing Record 33 of Set 7 | chardara
# Processing Record 34 of Set 7 | lavrentiya
# Processing Record 35 of Set 7 | nyagan
# Processing Record 36 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 7 | soyo
# Processing Record 38 of Set 7 | vetluzhskiy
# Processing Record 39 of Set 7 | litovko
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | viedma
# Processing Record 42 of Set 7 | pevek
# Processing Record 43 of Set 7 | tessalit
# Processing Record 44 of Set 7 | marsh harbour
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | tezu
# Processing Record 47 of Set 7 | brumado
# Processing Record 48 of Set 7 | ulaangom
# Processing Record 49 of Set 7 | fomboni
# Processing Record 50 of Set 7 | sinnamary
# Processing Record 1 of Set 8 | lhokseumawe
# Processing Record 2 of Set 8 | yaan
# Processing Record 3 of Set 8 | itarema
# Processing Record 4 of Set 8 | saint-joseph
# Processing Record 5 of Set 8 | verkh-usugli
# Processing Record 6 of Set 8 | abalak
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | souillac
# Processing Record 9 of Set 8 | ankazoabo
# Processing Record 10 of Set 8 | puerto lempira
# Processing Record 11 of Set 8 | hluti
# Processing Record 12 of Set 8 | bol
# Processing Record 13 of Set 8 | caraballeda
# Processing Record 14 of Set 8 | acapulco
# Processing Record 15 of Set 8 | talara
# Processing Record 16 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 8 | chimbote
# Processing Record 18 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | elk river
# Processing Record 20 of Set 8 | bongandanga
# Processing Record 21 of Set 8 | sakakah
# Processing Record 22 of Set 8 | conceicao do araguaia
# Processing Record 23 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 8 | sola
# Processing Record 25 of Set 8 | bilibino
# Processing Record 26 of Set 8 | abonnema
# Processing Record 27 of Set 8 | berdigestyakh
# Processing Record 28 of Set 8 | norwich
# Processing Record 29 of Set 8 | hungund
# Processing Record 30 of Set 8 | prado
# Processing Record 31 of Set 8 | alofi
# Processing Record 32 of Set 8 | tiksi
# Processing Record 33 of Set 8 | diapaga
# Processing Record 34 of Set 8 | yumen
# Processing Record 35 of Set 8 | itapirapua
# Processing Record 36 of Set 8 | flin flon
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | evansville
# Processing Record 39 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 8 | zabinka
# City not found. Skipping...
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | jinka
# Processing Record 43 of Set 8 | saint-augustin
# Processing Record 44 of Set 8 | ouesso
# Processing Record 45 of Set 8 | rocha
# Processing Record 46 of Set 8 | boralday
# Processing Record 47 of Set 8 | alpena
# Processing Record 48 of Set 8 | piacabucu
# Processing Record 49 of Set 8 | pisco
# Processing Record 50 of Set 8 | acajutla
# Processing Record 1 of Set 9 | odweyne
# Processing Record 2 of Set 9 | bahia blanca
# Processing Record 3 of Set 9 | makinsk
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | mackay
# Processing Record 6 of Set 9 | vila franca do campo
# Processing Record 7 of Set 9 | radhanpur
# Processing Record 8 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 9 | mangai
# Processing Record 11 of Set 9 | fier
# Processing Record 12 of Set 9 | venado tuerto
# Processing Record 13 of Set 9 | punto fijo
# Processing Record 14 of Set 9 | yaval
# Processing Record 15 of Set 9 | kamakwie
# Processing Record 16 of Set 9 | palmer
# Processing Record 17 of Set 9 | tarko-sale
# Processing Record 18 of Set 9 | belaya gora
# Processing Record 19 of Set 9 | avera
# Processing Record 20 of Set 9 | barquisimeto
# Processing Record 21 of Set 9 | tariba
# Processing Record 22 of Set 9 | bluefield
# Processing Record 23 of Set 9 | thomaston
# Processing Record 24 of Set 9 | tongliao
# Processing Record 25 of Set 9 | hay river
# Processing Record 26 of Set 9 | ketchikan
# Processing Record 27 of Set 9 | faya
# Processing Record 28 of Set 9 | atambua
# Processing Record 29 of Set 9 | vikindu
# Processing Record 30 of Set 9 | bud
# Processing Record 31 of Set 9 | mizdah
# Processing Record 32 of Set 9 | bereda
# Processing Record 33 of Set 9 | marienburg
# Processing Record 34 of Set 9 | xining
# Processing Record 35 of Set 9 | monrovia
# Processing Record 36 of Set 9 | esperance
# Processing Record 37 of Set 9 | porto walter
# Processing Record 38 of Set 9 | mixtepec
# City not found. Skipping...
# Processing Record 39 of Set 9 | karratha
# Processing Record 40 of Set 9 | khorixas
# Processing Record 41 of Set 9 | los llanos de aridane
# Processing Record 42 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 9 | menzelinsk
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | ternate
# Processing Record 46 of Set 9 | batavia
# Processing Record 47 of Set 9 | lichinga
# Processing Record 48 of Set 9 | amapa
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | wageningen
# Processing Record 1 of Set 10 | hami
# Processing Record 2 of Set 10 | san policarpo
# Processing Record 3 of Set 10 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 10 | kiama
# Processing Record 5 of Set 10 | synya
# Processing Record 6 of Set 10 | makubetsu
# Processing Record 7 of Set 10 | kutum
# Processing Record 8 of Set 10 | sidoarjo
# Processing Record 9 of Set 10 | olginskaya
# Processing Record 10 of Set 10 | gidam
# Processing Record 11 of Set 10 | hall
# Processing Record 12 of Set 10 | ambatofinandrahana
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | hofn
# Processing Record 15 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 10 | ishigaki
# Processing Record 17 of Set 10 | hovd
# Processing Record 18 of Set 10 | kloulklubed
# Processing Record 19 of Set 10 | qidong
# Processing Record 20 of Set 10 | kurilsk
# Processing Record 21 of Set 10 | camacha
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | kanniyakumari
# Processing Record 24 of Set 10 | karakol
# Processing Record 25 of Set 10 | artigas
# Processing Record 26 of Set 10 | malaya serdoba
# Processing Record 27 of Set 10 | chapais
# Processing Record 28 of Set 10 | jaumave
# Processing Record 29 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 10 | lucapa
# Processing Record 31 of Set 10 | wanning
# Processing Record 32 of Set 10 | omaruru
# Processing Record 33 of Set 10 | college
# Processing Record 34 of Set 10 | banda aceh
# Processing Record 35 of Set 10 | kavaratti
# Processing Record 36 of Set 10 | maragogi
# Processing Record 37 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 10 | boyolangu
# Processing Record 39 of Set 10 | airai
# Processing Record 40 of Set 10 | tornabe
# Processing Record 41 of Set 10 | sandwick
# Processing Record 42 of Set 10 | beira
# Processing Record 43 of Set 10 | beringovskiy
# Processing Record 44 of Set 10 | saint george
# Processing Record 45 of Set 10 | dana point
# Processing Record 46 of Set 10 | varkkallai
# Processing Record 47 of Set 10 | victoria
# Processing Record 48 of Set 10 | taicheng
# Processing Record 49 of Set 10 | sao miguel do araguaia
# Processing Record 50 of Set 10 | awjilah
# Processing Record 1 of Set 11 | krasnovishersk
# Processing Record 2 of Set 11 | haines junction
# Processing Record 3 of Set 11 | severiano melo
# Processing Record 4 of Set 11 | khvalynsk
# Processing Record 5 of Set 11 | samfya
# Processing Record 6 of Set 11 | hobyo
# Processing Record 7 of Set 11 | payo
# Processing Record 8 of Set 11 | pimentel
# Processing Record 9 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 11 | aldergrove
# Processing Record 11 of Set 11 | maraa
# Processing Record 12 of Set 11 | chuy
# Processing Record 13 of Set 11 | warri
# Processing Record 14 of Set 11 | wattegama
# Processing Record 15 of Set 11 | lata
# Processing Record 16 of Set 11 | kenora
# Processing Record 17 of Set 11 | bogalusa
# Processing Record 18 of Set 11 | zhanaozen
# Processing Record 19 of Set 11 | yar-sale
# Processing Record 20 of Set 11 | kanpur
# Processing Record 21 of Set 11 | nelson bay
# Processing Record 22 of Set 11 | nokaneng
# Processing Record 23 of Set 11 | waipawa
# Processing Record 24 of Set 11 | moron
# Processing Record 25 of Set 11 | namatanai
# Processing Record 26 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 27 of Set 11 | benjamin constant
# Processing Record 28 of Set 11 | alyangula
# Processing Record 29 of Set 11 | savannah bight
# Processing Record 30 of Set 11 | kuching
# Processing Record 31 of Set 11 | otradinskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | taoudenni
# Processing Record 33 of Set 11 | batemans bay
# Processing Record 34 of Set 11 | carballo
# Processing Record 35 of Set 11 | trofors
# Processing Record 36 of Set 11 | luganville
# Processing Record 37 of Set 11 | parry sound
# Processing Record 38 of Set 11 | arman
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | urumqi
# Processing Record 41 of Set 11 | andenes
# Processing Record 42 of Set 11 | semey
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | luderitz
# Processing Record 45 of Set 11 | san jeronimo
# Processing Record 46 of Set 11 | seminole
# Processing Record 47 of Set 11 | eldama ravine
# Processing Record 48 of Set 11 | itacarambi
# Processing Record 49 of Set 11 | punta alta
# Processing Record 50 of Set 11 | qui nhon
# Processing Record 1 of Set 12 | keshan
# City not found. Skipping...
# Processing Record 2 of Set 12 | qasigiannguit
# Processing Record 3 of Set 12 | nkhata bay
# Processing Record 4 of Set 12 | antalaha
# Processing Record 5 of Set 12 | adelaide
# Processing Record 6 of Set 12 | tevriz
# Processing Record 7 of Set 12 | krasnofarfornyy
# Processing Record 8 of Set 12 | chadiza
# Processing Record 9 of Set 12 | berlevag
# Processing Record 10 of Set 12 | aanekoski
# Processing Record 11 of Set 12 | apac
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | champasak
# Processing Record 14 of Set 12 | kismayo
# Processing Record 15 of Set 12 | belgaum
# Processing Record 16 of Set 12 | komsomolskiy
# Processing Record 17 of Set 12 | hasaki
# Processing Record 18 of Set 12 | liverpool
# Processing Record 19 of Set 12 | batyrevo
# Processing Record 20 of Set 12 | esil
# Processing Record 21 of Set 12 | pacific grove
# Processing Record 22 of Set 12 | lagoa
# Processing Record 23 of Set 12 | manta
# Processing Record 24 of Set 12 | pajapan
# Processing Record 25 of Set 12 | praia
# Processing Record 26 of Set 12 | kiunga
# Processing Record 27 of Set 12 | guanica
# Processing Record 28 of Set 12 | iaciara
# Processing Record 29 of Set 12 | guerrero negro
# Processing Record 30 of Set 12 | yerbogachen
# Processing Record 31 of Set 12 | henties bay
# Processing Record 32 of Set 12 | susanville
# Processing Record 33 of Set 12 | auki
# Processing Record 34 of Set 12 | matamoros
# Processing Record 35 of Set 12 | matara
# Processing Record 36 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 12 | palmas bellas
# Processing Record 38 of Set 12 | mount gambier
# Processing Record 39 of Set 12 | shu
# Processing Record 40 of Set 12 | nhulunbuy
# Processing Record 41 of Set 12 | fuyu
# Processing Record 42 of Set 12 | grootfontein
# Processing Record 43 of Set 12 | bambanglipuro
# Processing Record 44 of Set 12 | grand prairie
# Processing Record 45 of Set 12 | zhangye
# Processing Record 46 of Set 12 | stowe
# Processing Record 47 of Set 12 | gao
# Processing Record 48 of Set 12 | kendari
# Processing Record 49 of Set 12 | mingaora
# Processing Record 50 of Set 12 | clearwater
# Processing Record 1 of Set 13 | porto santo
# Processing Record 2 of Set 13 | mandera
# Processing Record 3 of Set 13 | douglas
# Processing Record 4 of Set 13 | tilichiki
# Processing Record 5 of Set 13 | howick
# Processing Record 6 of Set 13 | at-bashi
# Processing Record 7 of Set 13 | presidencia roque saenz pena
# Processing Record 8 of Set 13 | thohoyandou
# Processing Record 9 of Set 13 | taft
# Processing Record 10 of Set 13 | tukrah
# Processing Record 11 of Set 13 | tuy hoa
# Processing Record 12 of Set 13 | dalvik
# Processing Record 13 of Set 13 | rincon
# Processing Record 14 of Set 13 | albertville
# Processing Record 15 of Set 13 | kaduqli
# Processing Record 16 of Set 13 | eidsvag
# Processing Record 17 of Set 13 | richmond
# Processing Record 18 of Set 13 | gigmoto
# Processing Record 19 of Set 13 | barcelos
# Processing Record 20 of Set 13 | beyla
# Processing Record 21 of Set 13 | urengoy
# Processing Record 22 of Set 13 | denpasar
# Processing Record 23 of Set 13 | wasilla
# Processing Record 24 of Set 13 | novyy urengoy
# Processing Record 25 of Set 13 | corvallis
# Processing Record 26 of Set 13 | marzuq
# Processing Record 27 of Set 13 | richards bay
# Processing Record 28 of Set 13 | ilinskiy
# Processing Record 29 of Set 13 | latung
# Processing Record 30 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 13 | neuquen
# Processing Record 32 of Set 13 | yuryuzan
# Processing Record 33 of Set 13 | zabol
# Processing Record 34 of Set 13 | suihua
# Processing Record 35 of Set 13 | lyngseidet
# Processing Record 36 of Set 13 | agnibilekrou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     72.64        55           2
# 1       Ishurdi  24.1333   89.0833     81.28        86         100
# 2      Olafsvik  64.8945  -23.7142     50.32        83         100
# 3     Cape Town -33.9258   18.4232     68.38        56           0
# 4  Chino Valley  34.7575 -112.4538     97.41        15           0
# 5         Nikel  69.4128   30.2220     44.78        83          30
# 6       Salalah  17.0151   54.0924     84.29        79          40
# 7     Okakarara -20.5833   17.4333     45.18        58           0
# 8         Jitra   6.2681  100.4217     76.91       100          20
# 9      Coquimbo -29.9533  -71.3436     56.93        88          75
#
#    Wind Speed Country                 Date
# 0       12.30      PF  2022-06-07 22:44:05
# 1        8.90      BD  2022-06-07 22:44:05
# 2        3.62      IS  2022-06-07 22:44:06
# 3        3.44      ZA  2022-06-07 22:44:06
# 4       10.36      US  2022-06-07 22:44:06
# 5        8.72      RU  2022-06-07 22:44:07
# 6        6.91      OM  2022-06-07 22:44:07
# 7        6.33      NA  2022-06-07 22:44:07
# 8        3.44      MY  2022-06-07 22:44:08
# 9       10.36      CL  2022-06-07 22:44:08

# %%
# Reorder columns
new_column_order= ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Rikitea      PF  2022-06-07 22:44:05 -23.1203 -134.9692     72.64
# 1         Ishurdi      BD  2022-06-07 22:44:05  24.1333   89.0833     81.28
# 2        Olafsvik      IS  2022-06-07 22:44:06  64.8945  -23.7142     50.32
# 3       Cape Town      ZA  2022-06-07 22:44:06 -33.9258   18.4232     68.38
# 4    Chino Valley      US  2022-06-07 22:44:06  34.7575 -112.4538     97.41
# ..            ...     ...                  ...      ...       ...       ...
# 582      Yuryuzan      RU  2022-06-07 22:51:29  54.8633   58.4219     50.13
# 583         Zabol      AF  2022-06-07 22:51:30  32.2500   67.2500     67.41
# 584        Suihua      CN  2022-06-07 22:51:30  46.6406  126.9969     66.06
# 585    Lyngseidet      NO  2022-06-07 22:51:30  69.5763   20.2189     46.40
# 586  Agnibilekrou      CI  2022-06-07 22:51:31   7.1344   -3.2047     71.02
#
#      Humidity  Cloudiness  Wind Speed
# 0          55           2       12.30
# 1          86         100        8.90
# 2          83         100        3.62
# 3          56           0        3.44
# 4          15           0       10.36
# ..        ...         ...         ...
# 582        95         100        9.40
# 583        13           0        9.31
# 584        51           2        1.23
# 585        94          97        9.40
# 586        94          37        3.00
#
# [587 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%X")
today
# Out:
# '18:53:38'

# %%
### Plot Latitude vs. Temperature 6.3.1

# Import time module
import time

## Build the scatter plot for Latitude vs. Max Temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"),fontsize = 15)
plt.ylabel("Max Temperature (F)", fontsize = 12)
plt.xlabel("Latitude", fontsize = 12)
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
### Build the scatter plots for Latitude vs. Humidity.  6.3.2
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"),fontsize = 15)
plt.ylabel("Humidity (%)",fontsize = 12)
plt.xlabel("Latitude",fontsize = 12)
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
### Plot Latitude vs. Cloudiness 6.3.3

# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"),fontsize = 15)
plt.ylabel("Cloudiness (%)",fontsize = 12)
plt.xlabel("Latitude",fontsize = 12)
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
### Plot Latitude vs. Wind Speed  6.3.4

# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"), fontsize = 15)
plt.ylabel("Wind Speed (mph)", fontsize = 12)
plt.xlabel("Latitude", fontsize = 12)
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title, fontsize=15, weight ='bold')
    plt.xlabel('Latitude', fontsize=14)
    plt.ylabel(y_label, fontsize=14)
    plt.show()
plt.figure(figsize=(10, 10))
plot_linear_regression(lats, max_temps, "Latitude vs Max Temp", "Avg Max Temp",(-30,5))

# %%
#simply displaying the 13th city in our randomly generated list
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Busselton
# Country                        AU
# Date          2022-06-07 22:44:09
# Lat                        -33.65
# Lng                      115.3333
# Max Temp                    56.62
# Humidity                       54
# Cloudiness                    100
# Wind Speed                  19.15
# Name: 13, dtype: object

# %%
# We'll be creating a data from of hemispheres for northern and southern basd on latitude(Lat)

# To create a West and East hemisphere use same logic but using Longitude(Lng)

city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 1       Ishurdi      BD  2022-06-07 22:44:05  24.1333   89.0833     81.28
# 2      Olafsvik      IS  2022-06-07 22:44:06  64.8945  -23.7142     50.32
# 4  Chino Valley      US  2022-06-07 22:44:06  34.7575 -112.4538     97.41
# 5         Nikel      RU  2022-06-07 22:44:07  69.4128   30.2220     44.78
# 6       Salalah      OM  2022-06-07 22:44:07  17.0151   54.0924     84.29
#
#    Humidity  Cloudiness  Wind Speed
# 1        86         100        8.90
# 2        83         100        3.62
# 4        15           0       10.36
# 5        83          30        8.72
# 6        79          40        6.91

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
### Find the Correlation Between Latitude and Maximum Temperature  6.4.2
# Linear regression on the Northern Hemisphere by calling on function(def plot_linear_regression)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\n for Maximum Temperature', 'Max Temp',(10,20))

# %%
### Find the Correlation Between Latitude and Maximum Temperature  6.4.2
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature', 'Max Temp',(-50,90))

# %%
### Find the Correlation Between Latitude and Percent Humidity  6.4.3

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity', '% Humidity',(40,10))

# %%
### Find the Correlation Between Latitude and Percent Humidity  6.4.3

# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity', '% Humidity',(-50,15))

# %%
### Find the Correlation Between Latitude and Percent Cloudiness  6.4.4

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness', '% Cloudiness',(40,20))

# %%
### Find the Correlation Between Latitude and Wind Speed  6.4.5

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed', 'Wind Speed',(40,35))

# %%
### Find the Correlation Between Latitude and Wind Speed  6.4.5

# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plt.figure(figsize=(10,10))
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed', 'Wind Speed',(-35,20))
