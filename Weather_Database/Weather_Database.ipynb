# %%
import random
import numpy as np
import pandas as pd
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=825b4f9d7db94dffe76afa90bcc7ef84

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | brandfort
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | domoni
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | muros
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | sistranda
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | westport
# Processing Record 19 of Set 1 | tawang
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | christchurch
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | aswan
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | sept-iles
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | noumea
# Processing Record 34 of Set 1 | young
# Processing Record 35 of Set 1 | ugoofaaru
# Processing Record 36 of Set 1 | haines junction
# Processing Record 37 of Set 1 | okhotsk
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | tura
# Processing Record 45 of Set 1 | ilheus
# Processing Record 46 of Set 1 | mazarron
# Processing Record 47 of Set 1 | kautokeino
# Processing Record 48 of Set 1 | vestmanna
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | aykhal
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | ozernovskiy
# Processing Record 3 of Set 2 | parana
# Processing Record 4 of Set 2 | bolshoye polpino
# City not found. Skipping...
# Processing Record 5 of Set 2 | kahului
# Processing Record 6 of Set 2 | pustoshka
# Processing Record 7 of Set 2 | imbituba
# Processing Record 8 of Set 2 | cayenne
# Processing Record 9 of Set 2 | swan river
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | velyka mykhaylivka
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | cuiluan
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | kawambwa
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | navirai
# Processing Record 26 of Set 2 | stromness
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | kundiawa
# Processing Record 29 of Set 2 | palana
# Processing Record 30 of Set 2 | nuoro
# Processing Record 31 of Set 2 | ranikhet
# Processing Record 32 of Set 2 | cariamanga
# Processing Record 33 of Set 2 | sabha
# Processing Record 34 of Set 2 | poco das trincheiras
# Processing Record 35 of Set 2 | kamenka
# Processing Record 36 of Set 2 | yeppoon
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | erenhot
# Processing Record 39 of Set 2 | chernyshevskiy
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | pangnirtung
# Processing Record 42 of Set 2 | roald
# Processing Record 43 of Set 2 | zhangjiakou
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | port hawkesbury
# Processing Record 46 of Set 2 | itarema
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 3 | mount gambier
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | korocha
# Processing Record 4 of Set 3 | mataura
# Processing Record 5 of Set 3 | paamiut
# Processing Record 6 of Set 3 | ixtapa
# Processing Record 7 of Set 3 | yarmouth
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | eureka
# Processing Record 10 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 3 | homer
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | prince rupert
# Processing Record 16 of Set 3 | ferme-neuve
# Processing Record 17 of Set 3 | viedma
# Processing Record 18 of Set 3 | wahiawa
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | vostok
# Processing Record 21 of Set 3 | tadine
# Processing Record 22 of Set 3 | ca mau
# Processing Record 23 of Set 3 | verkh-usugli
# Processing Record 24 of Set 3 | natal
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | nome
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | moissala
# Processing Record 29 of Set 3 | huesca
# Processing Record 30 of Set 3 | bangkal
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | horta
# Processing Record 33 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 3 | camana
# Processing Record 35 of Set 3 | hobyo
# Processing Record 36 of Set 3 | mehamn
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | inuvik
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | makung
# City not found. Skipping...
# Processing Record 44 of Set 3 | dikson
# Processing Record 45 of Set 3 | campeche
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | bolshaya rechka
# Processing Record 48 of Set 3 | osoyoos
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | sompeta
# Processing Record 1 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 3 of Set 4 | kimbe
# Processing Record 4 of Set 4 | sola
# Processing Record 5 of Set 4 | pechenga
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | dingle
# Processing Record 9 of Set 4 | lazaro cardenas
# Processing Record 10 of Set 4 | korla
# Processing Record 11 of Set 4 | minab
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | olafsvik
# Processing Record 14 of Set 4 | naze
# Processing Record 15 of Set 4 | maniitsoq
# Processing Record 16 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 4 | koungou
# Processing Record 18 of Set 4 | coquimbo
# Processing Record 19 of Set 4 | bull savanna
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | quatre cocos
# Processing Record 22 of Set 4 | qasigiannguit
# Processing Record 23 of Set 4 | kilindoni
# Processing Record 24 of Set 4 | vigeland
# Processing Record 25 of Set 4 | orapa
# Processing Record 26 of Set 4 | kovvur
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | batagay-alyta
# Processing Record 29 of Set 4 | ngunguru
# Processing Record 30 of Set 4 | bredy
# Processing Record 31 of Set 4 | tagusao
# Processing Record 32 of Set 4 | kanye
# Processing Record 33 of Set 4 | gubbio
# Processing Record 34 of Set 4 | vanimo
# Processing Record 35 of Set 4 | saraland
# Processing Record 36 of Set 4 | kodinsk
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | mount pleasant
# Processing Record 39 of Set 4 | biltine
# Processing Record 40 of Set 4 | luza
# Processing Record 41 of Set 4 | zig
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | solnechnyy
# Processing Record 44 of Set 4 | udachnyy
# Processing Record 45 of Set 4 | spring valley
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | nuuk
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | pilar
# Processing Record 50 of Set 4 | bapatla
# Processing Record 1 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 5 | alekseyevsk
# Processing Record 3 of Set 5 | hornepayne
# Processing Record 4 of Set 5 | sur
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | dongtai
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | glasgow
# Processing Record 9 of Set 5 | havre-saint-pierre
# Processing Record 10 of Set 5 | aksarka
# Processing Record 11 of Set 5 | belaya gora
# Processing Record 12 of Set 5 | vadlapudi
# Processing Record 13 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 5 | shahr-e kord
# Processing Record 15 of Set 5 | bergen
# Processing Record 16 of Set 5 | havoysund
# Processing Record 17 of Set 5 | mount isa
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 5 | colac
# Processing Record 21 of Set 5 | mayo
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | hov
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | cap-aux-meules
# Processing Record 26 of Set 5 | central point
# Processing Record 27 of Set 5 | oktyabrskoye
# Processing Record 28 of Set 5 | blythe
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 31 of Set 5 | tulun
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | sisimiut
# Processing Record 35 of Set 5 | kolda
# Processing Record 36 of Set 5 | ancud
# Processing Record 37 of Set 5 | tazovskiy
# Processing Record 38 of Set 5 | tabuk
# Processing Record 39 of Set 5 | aberystwyth
# Processing Record 40 of Set 5 | surazh
# Processing Record 41 of Set 5 | saldanha
# Processing Record 42 of Set 5 | buin
# Processing Record 43 of Set 5 | maceio
# Processing Record 44 of Set 5 | harper
# Processing Record 45 of Set 5 | ariquemes
# Processing Record 46 of Set 5 | grimshaw
# Processing Record 47 of Set 5 | maarianhamina
# Processing Record 48 of Set 5 | kaitangata
# Processing Record 49 of Set 5 | guerrero negro
# Processing Record 50 of Set 5 | huangcun
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | pangody
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | corinto
# Processing Record 5 of Set 6 | sarai
# Processing Record 6 of Set 6 | kamaishi
# Processing Record 7 of Set 6 | mortka
# Processing Record 8 of Set 6 | henties bay
# Processing Record 9 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 6 | opuwo
# Processing Record 11 of Set 6 | morlaix
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | vesoul
# Processing Record 15 of Set 6 | olinda
# Processing Record 16 of Set 6 | huarmey
# Processing Record 17 of Set 6 | elat
# Processing Record 18 of Set 6 | mersing
# Processing Record 19 of Set 6 | ermelo
# Processing Record 20 of Set 6 | yilan
# Processing Record 21 of Set 6 | champerico
# Processing Record 22 of Set 6 | kargil
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | urumqi
# Processing Record 25 of Set 6 | shimoda
# Processing Record 26 of Set 6 | jeremoabo
# Processing Record 27 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 6 | matagami
# Processing Record 29 of Set 6 | horadiz
# Processing Record 30 of Set 6 | villa juarez
# Processing Record 31 of Set 6 | nador
# Processing Record 32 of Set 6 | tezu
# Processing Record 33 of Set 6 | acaponeta
# Processing Record 34 of Set 6 | nakambala
# Processing Record 35 of Set 6 | bundaberg
# Processing Record 36 of Set 6 | menongue
# Processing Record 37 of Set 6 | pangkalanbuun
# Processing Record 38 of Set 6 | new norfolk
# Processing Record 39 of Set 6 | tabou
# Processing Record 40 of Set 6 | kudahuvadhoo
# Processing Record 41 of Set 6 | pinillos
# Processing Record 42 of Set 6 | platanos
# Processing Record 43 of Set 6 | lufilufi
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | bengkulu
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | high rock
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 6 | marawi
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | pozo colorado
# Processing Record 3 of Set 7 | buraydah
# Processing Record 4 of Set 7 | fershampenuaz
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | hambantota
# Processing Record 7 of Set 7 | roblin
# Processing Record 8 of Set 7 | laguna
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | usinsk
# Processing Record 11 of Set 7 | patur
# Processing Record 12 of Set 7 | saravan
# Processing Record 13 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 14 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 7 | alexandria
# Processing Record 16 of Set 7 | svetlogorsk
# Processing Record 17 of Set 7 | correntina
# Processing Record 18 of Set 7 | gat
# Processing Record 19 of Set 7 | birao
# Processing Record 20 of Set 7 | ilulissat
# Processing Record 21 of Set 7 | baykit
# Processing Record 22 of Set 7 | narasannapeta
# Processing Record 23 of Set 7 | kieta
# Processing Record 24 of Set 7 | severnoye
# Processing Record 25 of Set 7 | shingu
# Processing Record 26 of Set 7 | shellbrook
# Processing Record 27 of Set 7 | nanhai
# Processing Record 28 of Set 7 | ballina
# Processing Record 29 of Set 7 | santa cruz
# Processing Record 30 of Set 7 | hithadhoo
# Processing Record 31 of Set 7 | svetlaya
# Processing Record 32 of Set 7 | altar
# Processing Record 33 of Set 7 | codrington
# Processing Record 34 of Set 7 | manadhoo
# Processing Record 35 of Set 7 | wad madani
# Processing Record 36 of Set 7 | muroto
# Processing Record 37 of Set 7 | muisne
# Processing Record 38 of Set 7 | memmingen
# Processing Record 39 of Set 7 | la ronge
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | college
# Processing Record 42 of Set 7 | nioro
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | berea
# Processing Record 45 of Set 7 | sioux lookout
# Processing Record 46 of Set 7 | borgosesia
# Processing Record 47 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 48 of Set 7 | grand gaube
# Processing Record 49 of Set 7 | khatanga
# Processing Record 50 of Set 7 | honningsvag
# Processing Record 1 of Set 8 | lucapa
# Processing Record 2 of Set 8 | krasnoarmeysk
# Processing Record 3 of Set 8 | camacha
# Processing Record 4 of Set 8 | verkhnevilyuysk
# Processing Record 5 of Set 8 | iqaluit
# Processing Record 6 of Set 8 | shetpe
# Processing Record 7 of Set 8 | paka
# Processing Record 8 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 8 | itoman
# Processing Record 10 of Set 8 | jinchang
# Processing Record 11 of Set 8 | galanta
# Processing Record 12 of Set 8 | paramirim
# Processing Record 13 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 8 | esperance
# Processing Record 15 of Set 8 | hays
# Processing Record 16 of Set 8 | bosaso
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | malm
# Processing Record 19 of Set 8 | kamyaran
# Processing Record 20 of Set 8 | dong hoi
# Processing Record 21 of Set 8 | nchelenge
# Processing Record 22 of Set 8 | slantsy
# Processing Record 23 of Set 8 | saint-ambroise
# Processing Record 24 of Set 8 | piacabucu
# Processing Record 25 of Set 8 | great yarmouth
# Processing Record 26 of Set 8 | annau
# Processing Record 27 of Set 8 | acarau
# Processing Record 28 of Set 8 | emerald
# Processing Record 29 of Set 8 | charleston
# Processing Record 30 of Set 8 | buchanan
# Processing Record 31 of Set 8 | kalemie
# Processing Record 32 of Set 8 | urdoma
# Processing Record 33 of Set 8 | kalabo
# Processing Record 34 of Set 8 | loikaw
# Processing Record 35 of Set 8 | okha
# Processing Record 36 of Set 8 | asau
# Processing Record 37 of Set 8 | brokopondo
# Processing Record 38 of Set 8 | coolum beach
# Processing Record 39 of Set 8 | teahupoo
# Processing Record 40 of Set 8 | ipixuna
# Processing Record 41 of Set 8 | kruisfontein
# Processing Record 42 of Set 8 | bambanglipuro
# Processing Record 43 of Set 8 | jishou
# Processing Record 44 of Set 8 | souillac
# Processing Record 45 of Set 8 | nova venecia
# Processing Record 46 of Set 8 | mari-turek
# Processing Record 47 of Set 8 | fort nelson
# Processing Record 48 of Set 8 | sao filipe
# Processing Record 49 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 8 | meulaboh
# Processing Record 1 of Set 9 | caravelas
# Processing Record 2 of Set 9 | yuanping
# Processing Record 3 of Set 9 | houma
# Processing Record 4 of Set 9 | lompoc
# Processing Record 5 of Set 9 | trincomalee
# Processing Record 6 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 9 | tiksi
# Processing Record 8 of Set 9 | maldonado
# Processing Record 9 of Set 9 | aguimes
# Processing Record 10 of Set 9 | prieska
# Processing Record 11 of Set 9 | brajrajnagar
# City not found. Skipping...
# Processing Record 12 of Set 9 | nizhnevartovsk
# Processing Record 13 of Set 9 | suntar
# Processing Record 14 of Set 9 | salinas
# Processing Record 15 of Set 9 | manakara
# Processing Record 16 of Set 9 | banjar
# Processing Record 17 of Set 9 | svetlyy
# Processing Record 18 of Set 9 | katherine
# Processing Record 19 of Set 9 | colonia
# Processing Record 20 of Set 9 | lodja
# Processing Record 21 of Set 9 | vila velha
# Processing Record 22 of Set 9 | san cristobal
# Processing Record 23 of Set 9 | san jose
# Processing Record 24 of Set 9 | ukiah
# Processing Record 25 of Set 9 | san policarpo
# Processing Record 26 of Set 9 | xining
# Processing Record 27 of Set 9 | stege
# Processing Record 28 of Set 9 | tuatapere
# Processing Record 29 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 9 | dabakala
# Processing Record 31 of Set 9 | douglas
# Processing Record 32 of Set 9 | cabras
# Processing Record 33 of Set 9 | bhilai
# Processing Record 34 of Set 9 | ayan
# Processing Record 35 of Set 9 | flin flon
# Processing Record 36 of Set 9 | ponta delgada
# Processing Record 37 of Set 9 | galle
# Processing Record 38 of Set 9 | northam
# Processing Record 39 of Set 9 | nakhon thai
# Processing Record 40 of Set 9 | sabang
# Processing Record 41 of Set 9 | borodino
# Processing Record 42 of Set 9 | buala
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | biak
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | umm kaddadah
# Processing Record 47 of Set 9 | nelson bay
# Processing Record 48 of Set 9 | ardmore
# Processing Record 49 of Set 9 | shizukuishi
# Processing Record 50 of Set 9 | salalah
# Processing Record 1 of Set 10 | birjand
# Processing Record 2 of Set 10 | rorvik
# Processing Record 3 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 10 | bubaque
# Processing Record 6 of Set 10 | green river
# Processing Record 7 of Set 10 | black river
# Processing Record 8 of Set 10 | kutum
# Processing Record 9 of Set 10 | boa vista
# Processing Record 10 of Set 10 | severo-yeniseyskiy
# Processing Record 11 of Set 10 | zeya
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 13 of Set 10 | tukrah
# Processing Record 14 of Set 10 | tabas
# Processing Record 15 of Set 10 | sasykoli
# Processing Record 16 of Set 10 | bonthe
# Processing Record 17 of Set 10 | faya
# Processing Record 18 of Set 10 | bud
# Processing Record 19 of Set 10 | vilhena
# Processing Record 20 of Set 10 | kuching
# Processing Record 21 of Set 10 | walvis bay
# Processing Record 22 of Set 10 | doka
# Processing Record 23 of Set 10 | te anau
# Processing Record 24 of Set 10 | concepcion del oro
# Processing Record 25 of Set 10 | rio pomba
# Processing Record 26 of Set 10 | kyren
# Processing Record 27 of Set 10 | karpathos
# Processing Record 28 of Set 10 | mackenzie
# Processing Record 29 of Set 10 | bagotville
# Processing Record 30 of Set 10 | sri aman
# Processing Record 31 of Set 10 | karasjok
# Processing Record 32 of Set 10 | monkey hill
# Processing Record 33 of Set 10 | sukumo
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | nidda
# Processing Record 36 of Set 10 | sorong
# Processing Record 37 of Set 10 | vaitape
# Processing Record 38 of Set 10 | hattiesburg
# Processing Record 39 of Set 10 | sambava
# Processing Record 40 of Set 10 | murud
# Processing Record 41 of Set 10 | touros
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | cockburn town
# Processing Record 44 of Set 10 | avera
# Processing Record 45 of Set 10 | fortuna
# Processing Record 46 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 10 | port lincoln
# Processing Record 48 of Set 10 | kisangani
# Processing Record 49 of Set 10 | sarny
# Processing Record 50 of Set 10 | whitianga
# Processing Record 1 of Set 11 | san lawrenz
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | saint-pierre
# Processing Record 4 of Set 11 | najran
# Processing Record 5 of Set 11 | balabac
# Processing Record 6 of Set 11 | auki
# Processing Record 7 of Set 11 | mamallapuram
# Processing Record 8 of Set 11 | ketchikan
# Processing Record 9 of Set 11 | sampit
# Processing Record 10 of Set 11 | toora-khem
# Processing Record 11 of Set 11 | carrigaline
# Processing Record 12 of Set 11 | duyun
# Processing Record 13 of Set 11 | abnub
# Processing Record 14 of Set 11 | wanning
# Processing Record 15 of Set 11 | marzuq
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | port-gentil
# Processing Record 18 of Set 11 | sharjah
# Processing Record 19 of Set 11 | silva jardim
# Processing Record 20 of Set 11 | alofi
# Processing Record 21 of Set 11 | kushmurun
# Processing Record 22 of Set 11 | ahipara
# Processing Record 23 of Set 11 | tashtagol
# Processing Record 24 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 25 of Set 11 | san rafael
# Processing Record 26 of Set 11 | adre
# Processing Record 27 of Set 11 | sakakah
# Processing Record 28 of Set 11 | tallahassee
# Processing Record 29 of Set 11 | sungaipenuh
# Processing Record 30 of Set 11 | asyut
# Processing Record 31 of Set 11 | khorixas
# Processing Record 32 of Set 11 | strezhevoy
# Processing Record 33 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 11 | marsh harbour
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | ranong
# Processing Record 37 of Set 11 | kajaani
# Processing Record 38 of Set 11 | pachino
# Processing Record 39 of Set 11 | russell
# Processing Record 40 of Set 11 | jacqueville
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | pinawa
# Processing Record 43 of Set 11 | verkhnyaya inta
# Processing Record 44 of Set 11 | batesville
# Processing Record 45 of Set 11 | grado
# Processing Record 46 of Set 11 | grindavik
# Processing Record 47 of Set 11 | maragogi
# Processing Record 48 of Set 11 | comodoro rivadavia
# Processing Record 49 of Set 11 | grevena
# Processing Record 50 of Set 11 | letpadan
# Processing Record 1 of Set 12 | baoning
# Processing Record 2 of Set 12 | tevaitoa
# Processing Record 3 of Set 12 | inirida
# Processing Record 4 of Set 12 | alenquer
# Processing Record 5 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 12 | belmonte
# Processing Record 7 of Set 12 | muravlenko
# Processing Record 8 of Set 12 | sao paulo de olivenca
# Processing Record 9 of Set 12 | bilma
# Processing Record 10 of Set 12 | valparaiso
# Processing Record 11 of Set 12 | lishui
# Processing Record 12 of Set 12 | tessalit
# Processing Record 13 of Set 12 | pisco
# Processing Record 14 of Set 12 | mbigou
# Processing Record 15 of Set 12 | dukat
# Processing Record 16 of Set 12 | zhengjiatun
# Processing Record 17 of Set 12 | nguruka
# Processing Record 18 of Set 12 | dunedin
# Processing Record 19 of Set 12 | klaksvik
# Processing Record 20 of Set 12 | ust-tsilma
# Processing Record 21 of Set 12 | bourail
# Processing Record 22 of Set 12 | altay
# Processing Record 23 of Set 12 | vestmannaeyjar
# Processing Record 24 of Set 12 | makakilo city
# Processing Record 25 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 12 | stepnyak
# Processing Record 27 of Set 12 | benguela
# Processing Record 28 of Set 12 | bowen
# Processing Record 29 of Set 12 | carballo
# Processing Record 30 of Set 12 | navrongo
# Processing Record 31 of Set 12 | yining
# Processing Record 32 of Set 12 | adana
# Processing Record 33 of Set 12 | artigas
# Processing Record 34 of Set 12 | huilong
# Processing Record 35 of Set 12 | magdagachi
# Processing Record 36 of Set 12 | geraldton
# Processing Record 37 of Set 12 | nhulunbuy
# Processing Record 38 of Set 12 | puerto salgar
# Processing Record 39 of Set 12 | batemans bay
# Processing Record 40 of Set 12 | vegreville
# Processing Record 41 of Set 12 | juneau
# Processing Record 42 of Set 12 | chara
# Processing Record 43 of Set 12 | constantine
# Processing Record 44 of Set 12 | port blair
# Processing Record 45 of Set 12 | tricase
# Processing Record 46 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 47 of Set 12 | manado
# Processing Record 48 of Set 12 | pontes e lacerda
# Processing Record 49 of Set 12 | port hardy
# Processing Record 50 of Set 12 | sar-e pul
# Processing Record 1 of Set 13 | kavaratti
# Processing Record 2 of Set 13 | bongandanga
# Processing Record 3 of Set 13 | takapau
# Processing Record 4 of Set 13 | florence
# Processing Record 5 of Set 13 | nanning
# Processing Record 6 of Set 13 | sao gabriel da cachoeira
# Processing Record 7 of Set 13 | morgan city
# Processing Record 8 of Set 13 | turtas
# Processing Record 9 of Set 13 | simpang empat
# Processing Record 10 of Set 13 | rocha
# Processing Record 11 of Set 13 | road town
# Processing Record 12 of Set 13 | santo amaro
# Processing Record 13 of Set 13 | celestun
# Processing Record 14 of Set 13 | broome
# Processing Record 15 of Set 13 | virginia beach
# Processing Record 16 of Set 13 | malakal
# Processing Record 17 of Set 13 | batagay
# Processing Record 18 of Set 13 | tigil
# Processing Record 19 of Set 13 | umea
# Processing Record 20 of Set 13 | mahon
# Processing Record 21 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 22 of Set 13 | husavik
# Processing Record 23 of Set 13 | ilhabela
# Processing Record 24 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | acapulco
# Processing Record 26 of Set 13 | tautira
# Processing Record 27 of Set 13 | old road
# City not found. Skipping...
# Processing Record 28 of Set 13 | waverly
# Processing Record 29 of Set 13 | sobolevo
# Processing Record 30 of Set 13 | naujoji akmene
# Processing Record 31 of Set 13 | padang
# Processing Record 32 of Set 13 | rozsypne
# Processing Record 33 of Set 13 | kemise
# Processing Record 34 of Set 13 | belyy yar
# Processing Record 35 of Set 13 | puerto leguizamo
# Processing Record 36 of Set 13 | dharchula
# Processing Record 37 of Set 13 | anadyr
# Processing Record 38 of Set 13 | oistins
# Processing Record 39 of Set 13 | oni
# Processing Record 40 of Set 13 | pedra
# Processing Record 41 of Set 13 | port augusta
# Processing Record 42 of Set 13 | praya
# Processing Record 43 of Set 13 | irawan
# Processing Record 44 of Set 13 | columbus
# Processing Record 45 of Set 13 | pochutla
# Processing Record 46 of Set 13 | abu dhabi
# Processing Record 47 of Set 13 | saquena
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | marang
# Processing Record 50 of Set 13 | barcelos
# Processing Record 1 of Set 14 | taoudenni
# Processing Record 2 of Set 14 | oriximina
# Processing Record 3 of Set 14 | aklavik
# Processing Record 4 of Set 14 | jackson
# Processing Record 5 of Set 14 | isangel
# Processing Record 6 of Set 14 | nikitinskiy
# Processing Record 7 of Set 14 | daru
# Processing Record 8 of Set 14 | cascais
# Processing Record 9 of Set 14 | kenai
# Processing Record 10 of Set 14 | bara
# Processing Record 11 of Set 14 | tramore
# Processing Record 12 of Set 14 | paramonga
# Processing Record 13 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 14 | chunoyar
# Processing Record 15 of Set 14 | novaya ladoga
# Processing Record 16 of Set 14 | capao da canoa
# Processing Record 17 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 18 of Set 14 | thessalon
# Processing Record 19 of Set 14 | stornoway
# Processing Record 20 of Set 14 | margate
# Processing Record 21 of Set 14 | xichang
# Processing Record 22 of Set 14 | odweyne
# Processing Record 23 of Set 14 | springdale
# Processing Record 24 of Set 14 | patrocinio
# Processing Record 25 of Set 14 | teguise
# Processing Record 26 of Set 14 | matata
# Processing Record 27 of Set 14 | marshfield
# Processing Record 28 of Set 14 | razgrad
# Processing Record 29 of Set 14 | abu samrah
# Processing Record 30 of Set 14 | huron
# Processing Record 31 of Set 14 | chimoio
# Processing Record 32 of Set 14 | tual
# Processing Record 33 of Set 14 | sumy
# Processing Record 34 of Set 14 | estelle
# Processing Record 35 of Set 14 | cuamba
# Processing Record 36 of Set 14 | flinders
# Processing Record 37 of Set 14 | zabol
# Processing Record 38 of Set 14 | turukhansk
# Processing Record 39 of Set 14 | dali
# Processing Record 40 of Set 14 | izhma
# Processing Record 41 of Set 14 | sturgeon bay
# Processing Record 42 of Set 14 | kaeo
# Processing Record 43 of Set 14 | yuli
# Processing Record 44 of Set 14 | tayoltita
# Processing Record 45 of Set 14 | nadym
# Processing Record 46 of Set 14 | akdepe
# Processing Record 47 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 14 | krasnokamensk
# Processing Record 49 of Set 14 | mangrol
# Processing Record 50 of Set 14 | leshukonskoye
# Processing Record 1 of Set 15 | morro bay
# Processing Record 2 of Set 15 | santa isabel do rio negro
# Processing Record 3 of Set 15 | uruana
# Processing Record 4 of Set 15 | uige
# Processing Record 5 of Set 15 | monrovia
# Processing Record 6 of Set 15 | ouro preto do oeste
# Processing Record 7 of Set 15 | point pedro
# Processing Record 8 of Set 15 | santarem
# Processing Record 9 of Set 15 | alice springs
# Processing Record 10 of Set 15 | buzescu
# Processing Record 11 of Set 15 | turinsk
# Processing Record 12 of Set 15 | jaciara
# Processing Record 13 of Set 15 | sibinal
# Processing Record 14 of Set 15 | nizhniy kuranakh
# Processing Record 15 of Set 15 | ustye
# Processing Record 16 of Set 15 | riyadh
# Processing Record 17 of Set 15 | tres passos
# Processing Record 18 of Set 15 | vagur
# Processing Record 19 of Set 15 | bria
# Processing Record 20 of Set 15 | taltal
# Processing Record 21 of Set 15 | providencia
# Processing Record 22 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 23 of Set 15 | almaznyy
# Processing Record 24 of Set 15 | baherden
# Processing Record 25 of Set 15 | byron bay
# Processing Record 26 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 27 of Set 15 | srednekolymsk
# Processing Record 28 of Set 15 | monroe
# Processing Record 29 of Set 15 | fomboni
# Processing Record 30 of Set 15 | puerto del rosario
# Processing Record 31 of Set 15 | gympie
# Processing Record 32 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 15 | harwich
# Processing Record 34 of Set 15 | salamanca
# Processing Record 35 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 15 | kuldiga
# Processing Record 37 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 15 | along
# Processing Record 39 of Set 15 | bulgan
# Processing Record 40 of Set 15 | bathsheba
# Processing Record 41 of Set 15 | uruacu
# Processing Record 42 of Set 15 | gulu
# Processing Record 43 of Set 15 | necochea
# Processing Record 44 of Set 15 | elizabeth city
# Processing Record 45 of Set 15 | dunkwa
# Processing Record 46 of Set 15 | tahoua
# Processing Record 47 of Set 15 | nogliki
# Processing Record 48 of Set 15 | ambilobe
# Processing Record 49 of Set 15 | sunrise manor
# Processing Record 50 of Set 15 | thinadhoo
# Processing Record 1 of Set 16 | boli
# Processing Record 2 of Set 16 | thai binh
# Processing Record 3 of Set 16 | agirish
# Processing Record 4 of Set 16 | komatsu
# Processing Record 5 of Set 16 | anandnagar
# Processing Record 6 of Set 16 | carnduff
# Processing Record 7 of Set 16 | wawa
# Processing Record 8 of Set 16 | wonthaggi
# Processing Record 9 of Set 16 | biliran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Tuktoyaktuk      CA  2022-02-05 16:54:49  69.4541 -133.0374    -31.00
# 1    Brandfort      ZA  2022-02-05 16:54:50 -28.7001   26.4597     72.81
# 2       Hobart      AU  2022-02-05 16:54:50 -42.8794  147.3294     60.03
# 3       Domoni      KM  2022-02-05 16:54:50 -12.2569   44.5319     79.81
# 4       Avarua      CK  2022-02-05 16:54:51 -21.2078 -159.7750     77.05
# 5        Bluff      NZ  2022-02-05 16:54:51 -46.6000  168.3333     50.11
# 6        Muros      ES  2022-02-05 16:50:37  42.7762   -9.0603     61.23
# 7    Mahebourg      MU  2022-02-05 16:54:51 -20.4081   57.7000     80.89
# 8    Namatanai      PG  2022-02-05 16:54:52  -3.6667  152.4333     79.95
# 9      Rikitea      PF  2022-02-05 16:53:44 -23.1203 -134.9692     78.62
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        68           0        9.22           clear sky
# 1        60          66       11.45       broken clouds
# 2        76         100        1.14     overcast clouds
# 3        85          82        7.72          light rain
# 4        88          40        8.05    scattered clouds
# 5        81          36        8.30    scattered clouds
# 6        55          10       14.65           clear sky
# 7        83          40       16.11    scattered clouds
# 8        80          81        8.14       broken clouds
# 9        73          53       12.82       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
